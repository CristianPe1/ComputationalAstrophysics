# %% [markdown]
# Lectura de archivos .fitz, lectura de imagenes

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import make_lupton_rgb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9245c0773a13> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from astropy.io import make_lupton_rgb
#
# ImportError: cannot import name 'make_lupton_rgb' from 'astropy.io' (/usr/local/lib/python3.8/dist-packages/astropy/io/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
i = hduli[0].data

# %%
plt.figure(figsize=(10,10))
plt.imshow(i,cmap='gray')
plt.show()

# %% [markdown]
# Composicion de colores RGB

# %%
rgb_composite = make_lupton_rgb(r,g,u)

# %%
plt.figure(figsize=(10,10))
plt.imshow(rgb_composite,origin='lower')
plt.show()

# %% [markdown]
# Composicion de colores rg

# %%
rgb_composite = make_lupton_rgb(i,r,g,minimum=10 , steretch=1, Q=9)#Cambiar los espectros 

plt.figure(figsize=(10,10))
plt.imshow(rgb_composite,origin='lower')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0845a336245a> in <module>
# ----> 1 rgb_composite = make_lupton_rgb(i,r,g,minimum=10 , steretch=1, Q=9)#Cambiar los espectros
#       2
#       3 plt.figure(figsize=(10,10))
#       4 plt.imshow(rgb_composite,origin='lower')
#       5 plt.show()
#
# NameError: name 'make_lupton_rgb' is not defined
