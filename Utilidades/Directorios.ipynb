# %%
import os

# %%
cwd = os.getcwd()
cwd
# Out:
# '/content'

# %%
 print("Current working directory: {0}".format(cwd))
# Out:
# Current working directory: /content

# %%
os.path.realpath("Directorios.ipynb")
# Out:
# '/content/Directorios.ipynb'

# %%
os.listdir(cwd)
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mainpath = "drive/MyDrive/Colab Notebooks/Astrofísica Computacional/Data/"

print("Current working directory: {0}".format(mainpath))
# Out:
# Current working directory: drive/MyDrive/Colab Notebooks/Astrofísica Computacional/Data/

# %%
os.listdir(mainpath)
# Out:
# ['J_other_Ap_63.322', 'J_ApJ_585_647', 'J_ApJ_733_60']
