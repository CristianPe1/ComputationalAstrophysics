# %%
import numpy as np
2import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

# %%
hdul = fits.open()#data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4ca8f04341cf> in <module>
# ----> 1 hdul = fits.open()
#
# TypeError: fitsopen() missing 1 required positional argument: 'name'

# %%
hdul[1].header#Fecha juliana ??????
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0d8b2c751d41> in <module>
# ----> 1 hdul[1].header
#
# NameError: name 'hdul' is not defined

# %%
data = hdul[0].data
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d56cc792adba> in <module>
# ----> 1 data = hdul[0].data
#       2 data
#
# NameError: name 'hdul' is not defined

# %%
plt.figure(figsize=(5,5))
plt.imshow(data, origin = "lower", cmap = "inferno")
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-32db8c8e6d28> in <module>
#       1 plt.figure(figsize=(5,5))
# ----> 2 plt.imshow(data, origin = "lower", cmap = "inferno")
#       3 plt.colorbar()
#       4 plt.show()
#
# NameError: name 'data' is not defined

# %%
from astropy.wcs import WCS

# %%
coord = WCS(hdul[1].header)
coord
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-910ce19a679a> in <module>
# ----> 1 coord = WCS(hdul[1].header)
#       2 coord
#
# NameError: name 'hdul' is not defined

# %%
from astropy.coordinates import SkyCoord

# %%
SkyCoord.from_pixel(0,0,coord)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d4e8b1bc1c47> in <module>
# ----> 1 SkyCoord.from_pixel(0,0,coord)
#
# NameError: name 'coord' is not defined

# %%
SkyCoord.to_pixel(coord)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c4d03d8f81e9> in <module>
# ----> 1 SkyCoord.to_pixel(coord)
#
# NameError: name 'coord' is not defined

# %%
SkyCoord.from_name("Cas A")
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (350.85, 58.815)>

# %%
CasA_possition = SkyCoord.from_name("Cas A")
CasA_possition
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (350.85, 58.815)>

# %%
CasA_possition.to_pixel(coord)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-003761561208> in <module>
# ----> 1 CasA_possition.to_pixel(coord)
#
# NameError: name 'coord' is not defined

# %%
coord(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-10d1e1a25e20> in <module>
# ----> 1 coord(0)
#
# NameError: name 'coord' is not defined

# %%
plt.figure(figsize=(5,5))
ax = plt.subplot(projection=coord)
ax.imshow(data, origin = "lower", cmap = "inferno")
#Que hicieron con scatter --- coordenadas del punto ?????
ax.scatter(reCasA,deCasA,transform = ax.set_transform )
ax.set_xlabel("RA [deg]")
ax.set_ylabel("dec")
plt.show()

# %%
CasA_possition.icrs.dec.deg#?????
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-365b704b37c6> in <module>
# ----> 1 CasA_position.icrs.dec.deg
#
# NameError: name 'CasA_position' is not defined

# %%
CasA_possition.icrs.dec.deg

# %%
#Colocar un circulo para encerrar a cayopedia
plpt.cuircle
circle=plt.Circle((0,0),2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-dfad0168253b> in <module>
#       1 #Colocar un circulo para encerrar a cayopedia
# ----> 2 plpt.cuircle
#       3 circle=plt.Circle((0,0),2)
#       4 plt.show()
#
# NameError: name 'plpt' is not defined

# %%
import matplotlib.pyplot as plt

circle1 = plt.Circle((0, 0), 0.2, color='r')
circle2 = plt.Circle((0.5, 0.5), 0.2, color='b')
circle3 = plt.Circle((1, 1), 0.2, color='g', clip_on=False)

fig, ax = plt.subplots() # note we must use plt.subplots, not plt.subplot
# (or if you have an existing figure)
# fig = plt.gcf()
# ax = fig.gca()

ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)

fig.savefig('plotcircles.png')
