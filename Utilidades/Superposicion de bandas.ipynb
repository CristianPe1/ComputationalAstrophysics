# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

# %%
#CARGA DE DATOS

# %%
hdul.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9ffb223c5c52> in <module>
# ----> 1 hdul.info()
#
# NameError: name 'hdul' is not defined

# %%
hdul["Primary"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-28678baa3040> in <module>
# ----> 1 cahdul["Primary"]
#
# NameError: name 'cahdul' is not defined

# %%
hdul[1].HEADER
#Flujo vs frecuencia --- espectro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d44001dcaffb> in <module>
# ----> 1 hdul[1].HEADER
#       2 #Flujo vs frecuencia --- espectro
#
# NameError: name 'hdul' is not defined

# %%
hdul[1].columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cea60fe6d970> in <module>
# ----> 1 hdul[1].columns
#
# NameError: name 'hdul' is not defined

# %%
spectrum_data = hdul[1].data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-50c43be7bae3> in <module>
# ----> 1 spectrum_data = hdul[1].data
#
# NameError: name 'hdul' is not defined

# %%
type(spectrum_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e0cc74e185e8> in <module>
# ----> 1 type(spectrum_data)
#
# NameError: name 'spectrum_data' is not defined

# %%
3spectrum_data = Table(hdul[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-54c82d0252ae> in <module>
# ----> 1 spectrum_data = Table(hdul[1])
#
# NameError: name 'hdul' is not defined

# %%
spectrum_data["flux"]#ergs*s/cm2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8e3140ef529c> in <module>
# ----> 1 spectrum_data["flux"]#ergs*s/cm2
#
# NameError: name 'spectrum_data' is not defined

# %%
plt.figure(figsize=(7,5))
plt.hist(spectrum_data["flux"],bins="auto")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bfae39c7b88f> in <module>
#       1 plt.figure(figsize=(7,5))
# ----> 2 plt.hist(spectrum_data["flux"],bins="auto")
#       3 plt.show()
#
# NameError: name 'spectrum_data' is not defined

# %%
plt.figure(figsize=(10,8))
plt.plot(spectrum_data["log lam"],spectrum_data["flux"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-96934e900bc2> in <module>
#       1 plt.figure(figsize=(10,8))
# ----> 2 plt.plot(spectrum_data["log lam"],spectrum_data["flux"])
#       3 plt.show()
#
# NameError: name 'spectrum_data' is not defined

# %%
wave = np.power(10,spectrum_data["log lam"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3e907936774d> in <module>
# ----> 1 wave = np.power(10,spectrum_data["log lam"])
#
# NameError: name 'spectrum_data' is not defined

# %%
plt.figure(figsize=(10,8))
plt.plot(wave,spectrum_data["flux"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7436242430dc> in <module>
#       1 plt.figure(figsize=(10,8))
# ----> 2 plt.plot(wave,spectrum_data["flux"])
#       3 plt.show()
#
# NameError: name 'wave' is not defined

# %%
spectrum_data.add(wave, name="wave")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4db33222e92d> in <module>
# ----> 1 spectrum_data.add(wave, name="wavw")
#
# NameError: name 'spectrum_data' is not defined
